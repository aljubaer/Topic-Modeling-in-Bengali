# %%
from bs4 import BeautifulSoup
import re
import requests

# %%
headers = {"User-agent":"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/47.0.2526.80 Safari/537.36"}
headers = {}

# %%
def crawl_prothom_alo(start_date_str, end_date_str):
    from datetime import datetime, timedelta
    base_url = "https://www.prothomalo.com"
    archive_url = base_url+"/archive/"
    start_date = datetime.strptime(start_date_str, "%Y-%m-%d")
    end_date = datetime.strptime(end_date_str, "%Y-%m-%d")
    delta = end_date - start_date
	
    for i in range(delta.days + 1):

        date = start_date + timedelta(days = i)
        url = archive_url+date.strftime("%Y-%m-%d")
        infile = open('newspaper/prothom_alo_'+ date.strftime("%Y-%m-%d") + ".txt", "w+", encoding = 'utf-8')
        while url:
            print("reading url >>> "+url)
            try:
                html_content = requests.get(url, headers = headers).content
            except:
                print('Connection Problem for url: ', url, '. Skipping it.')
                break
            soup = BeautifulSoup(html_content, "lxml")
            links = soup.findAll('a', {'class': 'link_overlay'}, href = True)
            for link in links:
                try:
                    inner_html_content = requests.get(base_url+link['href'], headers = headers).content
                except:
                    print('Connection Problem for article, url: ', base_url+link['href'])
                    continue
                inner_soup = BeautifulSoup(inner_html_content, "lxml")
                articleBody = inner_soup.find('div', {'itemprop': 'articleBody'})
                if articleBody:
                    headline = inner_soup.find('div', {'class': 'right_title'}).text
                    print("headline >>> "+headline)
                    infile.write(headline+"\n")
                    infile.write(str(articleBody.text) + '\n\n')
			
            pagination_div = soup.find('div', {'class': 'pagination'})
            url = None
            if pagination_div:
                next_page_link = pagination_div.find('a', {'class': 'next_page'}, href = True)
                if next_page_link:
                    url = next_page_link['href']
        infile.close()

# %%
crawl_prothom_alo("2019-09-02","2019-09-02")
# Out:
# reading url >>> https://www.prothomalo.com/archive/2019-09-02
# headline >>>
# কোরিয়ায় আন্তর্জাতিক শিক্ষার্থীদের সংগঠনের প্রীতিসভা
#
# headline >>>
# সড়ক দুর্ঘটনায় দুই ভাইসহ তিন রোহিঙ্গা নিহত
#
# headline >>>
# বিশ্বকাপের পথে আরেকটু এগিয়ে গেল বাংলাদেশ
#
# headline >>>
# বৌভাত শেষে বাবার বাড়ি ফেরা হলো না নববধূর
#
# headline >>>
# মেসে কলেজছাত্রীর ঝুলন্ত লাশ
#
# headline >>>
# মিথ্যা তথ্যে ‘মুক্তিযোদ্ধা কোটায়’ চাকরি, অবশেষে ধরা
#
# headline >>>
# বাংলাদেশ ১০ বছর ধরে প্রবৃদ্ধিতে শীর্ষে : অর্থমন্ত্রী
#
# headline >>>
# ‘লাখ-লাখ টাকাই সবকিছু নয়’
#
# headline >>>
# ফোনে পরিচয় থেকে প্রেম, ডেকে নিয়ে ধর্ষণ
#
# headline >>>
# রোহিঙ্গাদের মুঠোফোন সেবা বন্ধের নির্দেশ: যথাযথ পদক্ষেপ নেবে অ্যামটব
#
# headline >>>
# গণশৌচাগারের দেয়ালে নাজিরের পটচিত্র
#
# headline >>>
# ভারতীয়রা দেখতে পাবেন বিটিভি
#
# headline >>>
# হাতিরঝিল থানার নাশকতার মামলায় ফখরুলসহ বিএনপির ৮ নেতার জামিন
#
# headline >>>
# বিরতির পর ফিরেছেন মেহরাব
#
# headline >>>
# নিজের সিট ছেড়ে গণরুমে উঠলেন ডাকসু নেতা
#
# headline >>>
# চার কারণে অভিযোগপত্রে আয়শার নাম, বলছে বরগুনার পুলিশ
#
# headline >>>
# ট্রেনের ছাদে ভ্রমণ, ১৩ জন আটক
#
# headline >>>
# জুবায়ের শিখতে চান রশিদ খানের কাছ থেকে
#
# headline >>>
# যশোরে বন্ধুদের সহায়তায় স্বামীকে খুন করেন স্ত্রী, বলছে পিবিআই
#
# headline >>>
# দুর্ঘটনায় মারাত্মক আহত কেভিন হার্ট
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=2
# headline >>>
# আবারও বাকশাল? এত সোজা নয়: ফখরুল
#
# headline >>>
# বাবার ক্যানসারের কথা শুনে কেঁদেছেন রণবীর
#
# headline >>>
# সেকাল একাল
#
# headline >>>
# ব্রেক্সিট: দলীয় বিদ্রোহীদের বহিষ্কার করবেন ব্রিটিশ প্রধানমন্ত্রী
#
# headline >>>
# জাল দলিলে বিডিবিএলের ১৭৪ কোটি টাকা আত্মসাৎ
#
# headline >>>
# অস্ত্র মামলায় এক ব্যক্তির ১০ বছর কারাদণ্ড
#
# headline >>>
# মুশফিকদের বল করে হাত পাকাচ্ছেন নাঈম
#
# headline >>>
# ঠাকুরগাঁওয়ে মেস থেকে কলেজছাত্রীর ঝুলন্ত লাশ উদ্ধার
#
# headline >>>
# ৫০ টাকা ভাড়ায় যাত্রী নিয়ে প্রাণ হারান মিলন
#
# headline >>>
# রাবিতে ভর্তি পরীক্ষার আবেদন শুরু কাল থেকে
#
# headline >>>
# রাজশাহী বিশ্ববিদ্যালয়ের সমাবর্তন ৩০ নভেম্বর
#
# headline >>>
# কুমারখালীতে ডিজিটাল পদ্ধতিতে নামজারির টাকা আদায়
#
# headline >>>
# মেসি-রোনালদোকে আবারও দর্শক বানাবেন ডাইক?
#
# headline >>>
# আফগান–স্পিনে দিশেহারা বিসিবি একাদশ
#
# headline >>>
# জোড় তারিখে সবুজ, বিজোড় তারিখে লাল ইজিবাইক
#
# headline >>>
# বিএসএফের গুলিতে ১০ বাংলাদেশি আহত
#
# headline >>>
# রোহিঙ্গাদের মোবাইল সুবিধা বন্ধের নির্দেশ
#
# headline >>>
# বৃষ্টিতে পথে এসে দাঁড়ালেন শ্রদ্ধা
#
# headline >>>
# খুলনা বিশ্ববিদ্যালয়ের সমাবর্তন ২২ ডিসেম্বর
#
# headline >>>
# রোহিঙ্গা প্রত্যাবাসনে কূটনীতির দ্বিতীয় পথ
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=3
# headline >>>
# তলোয়ার নিয়ে কাশ্মীরের জন্য লড়বেন মিয়াঁদাদ
#
# headline >>>
# মাদক মামলায় দুই যুবকের মৃত্যুদণ্ড
#
# headline >>>
# সাউন্ড বক্স বাজানোকে কেন্দ্র করে দুই পক্ষের সংঘর্ষে আহত ৩০
#
# headline >>>
# শ্রমিকদের কর্মবিরতি, কনটেইনার পরিবহনে অচলাবস্থা
#
# headline >>>
# আসামে এনআরসি: আতঙ্কে ভারতের গোর্খা ও মতুয়া সম্প্রদায়
#
# headline >>>
# পাহাড়ের কোলে
#
# headline >>>
# টরন্টোয় নরসিংদীবাসীর বনভোজন
#
# headline >>>
# মোজাফফরের শোকসভায় মুক্তিযুদ্ধের পক্ষের ঐক্যের ডাক
#
# headline >>>
# র‌্যাবের সঙ্গে ‘বন্দুকযুদ্ধে’ নিহত ১
#
# headline >>>
# স্বর্ণসহ ৫টি রপ্তানি পদক পেল প্রাণ-আরএফএল
#
# headline >>>
# টানা চার দিন ধরে দরপতনে পুঁজিবাজার
#
# headline >>>
# বিপিএল এবার হবে তো?
#
# headline >>>
# বটতলার ১১ বছর
#
# headline >>>
# ৬৮ সংস্থার কাছে ২ লাখ কোটি ‘অলস’ টাকা
#
# headline >>>
# নদীতে মাছ ধরে জীবন চলে তাঁদের
#
# headline >>>
# স্ত্রীর হত্যাকাণ্ড এখনো তাড়া করছে পোলানস্কিকে
#
# headline >>>
# আসামে এনআরসির গুমর ফাঁস
#
# headline >>>
# হেপাটাইটিস বি পজিটিভ যেভাবে বুঝবেন
#
# headline >>>
# রোহিঙ্গা শিবিরে এনজিও কার্যক্রম নিয়ে বিভ্রান্তি
#
# headline >>>
# আবদুল আলীমের গান শোনাবেন দুই ছেলে
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=4
# headline >>>
# দলবদল: তুরস্ক গেলেন ফ্যালকাও
#
# headline >>>
# ইরানের সঙ্গে দ্বন্দ্বে কি পশ্চিমা জোট ভেঙে যাবে
#
# headline >>>
# রূপসাপাড়ে জাহাজ নির্মাণযজ্ঞ
#
# headline >>>
# গান গেয়ে ধান রোপণ
#
# headline >>>
# নৌ অধিদপ্তরের শিপ সার্ভেয়ার আটক
#
# headline >>>
# তিন সেতুতে বিশ্বব্যাংক, চীনের সাড়া নেই
#
# headline >>>
# রিয়াল–বার্সার চেয়েও এগিয়ে যাচ্ছে অ্যাটলেটিকো
#
# headline >>>
# বাবরের মৃত্যু নতুন করে ভাবায়
#
# headline >>>
# দক্ষিণ এশীয় স্পিকার সম্মেলনে ভারত-পাকিস্তানের মধ্যে উত্তপ্ত বাক্যবিনিময়
#
# headline >>>
# বাস চালানোর প্রথম দিনই কৃষ্ণার পায়ে চাপা দেন চালক
#
# headline >>>
# ইকার্দি যাচ্ছেন পিএসজিতে?
#
# headline >>>
# উন্নয়নে জাহাঙ্গীরনগর বিশ্ববিদ্যালয়
#
# headline >>>
# পানি–মাটি পরীক্ষায় জানা যাবে মাছের প্রজাতি
#
# headline >>>
# কম্বলে মুড়ে হিমবাহ রক্ষা
#
# headline >>>
# নীলফামারীতে শুরু হলো মাসব্যাপী বাণিজ্যমেলা
#
# headline >>>
# রোহিঙ্গা সংকট থেকে উত্তরণের পথ কী
#
# headline >>>
# আলোকে ছায়া থেকে রক্ষার লড়াই
#
# headline >>>
# ছাত্রলীগের দুপক্ষের সংঘর্ষের পর নোয়াখালী বিজ্ঞান ও প্রযুক্তি বিশ্ববিদ্যালয়ের হল বন্ধ
#
# headline >>>
# ডেঙ্গু : সবার নজর সেপ্টেম্বরে
#
# headline >>>
# সাতরঙা অর্থনীতি
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=5
# headline >>>
# চাকরিতে নারীর সংখ্যা বাড়ছে
#
# headline >>>
# বিভিন্ন দেশ নিয়ে তাঁর কাজ
#
# headline >>>
# ‘এনআরসির নামে ভারত থেকে কাউকে তাড়ানো যাবে না’
#
# headline >>>
# নারী ডিসিদের ব্যতিক্রমী উদ্যোগ প্রশংসিত হচ্ছে
#
# headline >>>
# হটলাইন ৩৩৩, বন্ধ হচ্ছে বাল্যবিবাহ
#
# headline >>>
# শিশু বিকাশে তুবার ‘লাটিম’
#
# headline >>>
# নতুন আইন করতে লড়েছেন শেরি
#
# headline >>>
# আয়শার কারামুক্তিতে আইনগত বাধা নেই
#
# headline >>>
# ৯৮ বছর বয়সে ছবির প্রদর্শনী
#
# headline >>>
# শ্রম সবখানেই গুরুত্বপূর্ণ ও মূল্যবান
#
# headline >>>
# ঘূর্ণিঝড় ডোরিয়ানে লন্ডভন্ড বাহামা
#
# headline >>>
# পার্কে থাকা রান্নাঘর উচ্ছেদ নিয়ে তুলকালাম
#
# headline >>>
# ঝুঁকি নিয়ে ভাঙা সেতু পারাপার
#
# headline >>>
# লাল-সবুজে মোড়ানো বিদ্যালয়
#
# headline >>>
# নিম্নমানের ধান কিনতে চাপ
#
# headline >>>
# ভালো ভালো কাজের নেশা তাঁদের তাড়িয়ে বেড়ায়: শাকিব খান
#
# headline >>>
# কোয়েল পালনে ঘুরে গেল ভাগ্যের চাকা
#
# headline >>>
# মেয়র সাঈদ খোকনের দাবি ১০ মিনিটও টেকেনি
#
# headline >>>
# কুমিল্লায় একই স্থানে দুর্ঘটনার পর দুর্ঘটনা, এএসআইসহ নিহত ৩
#
# headline >>>
# সবুজের সেঞ্চুরি
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=6
# headline >>>
# চোট বিদায় করে দিল জোকোভিচকে
#
# headline >>>
# পাপ-পুণ্যে নতুন নায়িকা সুমী
#
# headline >>>
# গাড়ি কিনুন ঋণে
#
# headline >>>
# নাগরিকপঞ্জি ভারতের অভ্যন্তরীণ ব্যাপার নয়
#
# headline >>>
# সূর্যের আলোতেই কাজ
#
# headline >>>
# সোনাই এখন সবচেয়ে খাঁটি
#
# headline >>>
# ব্র্যান্ডের গল্প : ‘সুপারস্টার’ ব্রাদার্স
#
# headline >>>
# শীর্ষ ১% ধনী নিয়ে পাঁচ রকম তথ্য
#
# headline >>>
# স্টার্টআপ : শুরুর আগে শুরু
#
# headline >>>
# ব্যাটারির শক্তিতে বিস্কুটে সাফল্য
#
# headline >>>
# ঘটনাটি অভূতপূর্ব ইতিহাসে প্রথম
#
# headline >>>
# বিজেপি বলছে, ভুলে ভরা তালিকা মানি না
#
# headline >>>
# উদ্যোক্তাদের ঠিকানা ‘মোড়’
#
# headline >>>
# নৃশংস জোকার প্রশংসিত
#
# headline >>>
# ভিনদেশের বন্দরে লাল–সবুজ পতাকা
#
# headline >>>
# বস্তির বাসিন্দারা সিন্ডিকেটের হাতে জিম্মি
# অবৈধ গ্যাস ও বিদ্যুৎ–সংযোগ
#
# headline >>>
# সিঁড়ির পর সিঁড়ি বেয়ে ওপরে উঠতে হয়
#
# headline >>>
# কৃষ্ণা রায়কে চাপা দেওয়া বাসচালক গ্রেপ্তার
#
# headline >>>
# পুরাকীর্তিটি রক্ষার উদ্যোগ নিন
# ‘বড়কুঠি’তে বিয়ের অনুষ্ঠান!
#
# headline >>>
# ভিউ পেতে নাটকের উদ্ভট নাম
#
# reading url >>> https://www.prothomalo.com/archive/2019-09-02?page=7
# headline >>>
# মালিঙ্গার যে রেকর্ড ডাকছে সাকিবকে
#
# headline >>>
# ময়মনসিংহে ‘বন্দুকযুদ্ধে’ নিহত ১
#
# headline >>>
# স্কুলছাত্রী স্মৃতি গণধর্ষণ-হত্যা মামলার প্রধান আসামি গ্রেপ্তার
#
# headline >>>
# কোলো–বিউটিদের হাসপাতালে এক দিন...
#
# headline >>>
# টানা পতনে কমেছে লেনদেনও
#
# headline >>>
# মহেশখালীতে র‍্যাবের সঙ্গে ‘বন্দুকযুদ্ধে’ নিহত ১
#
# headline >>>
# অটিস্টিক-প্রতিবন্ধীদের চাকরির খোঁজ
#
# headline >>>
# ডেঙ্গুতে আরও চারজনের মৃত্যু
#
# headline >>>
# সেই খাট নিয়ে বিভক্ত শিক্ষক-শিক্ষার্থীরা
#
# headline >>>
# সেকেন্ডেরও কম সময়ে হাজার মাইল পিছিয়ে বাংলাদেশ
#
# headline >>>
# দ্বিতীয় বিশ্বযুদ্ধ নিয়ে ক্ষমা চাইলেন জার্মান প্রেসিডেন্ট
#
# headline >>>
# ‘পিস্তল ঠেকিয়ে স্বীকারোক্তি দিতে বাধ্য করে পুলিশ’
#
# headline >>>
# বেলের জোড়া গোলেও জয় পেল না রিয়াল
#
# headline >>>
# ড্রোন হামলার জবাবে ইসরায়েলের সামরিক ঘাঁটিতে হিজবুল্লাহর রকেট হামলা
